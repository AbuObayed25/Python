# %% [markdown]
# <a href="https://colab.research.google.com/github/AbuObayed25/Python/blob/AI/AI_Week3_6250.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Agenda **
# # DFS and water jug problem
# Depth -> left -> Right-> Root

# %%
graph = {
    '5':['3','7'],
    '3':['2','4'],
    '7':['8'],
    '2':[],
    '4':['8'],
    '8':[]

}

# %%
def dfs_iterative(graph,start_node):
  visited =set()
  stack=[start_node]
  while stack:
    node = stack.pop()
    if node not in visited:
      print(node)
      visited.add(node)
      stack.extend(graph[node])

#Driver code
print("Following is the Depth-First Search (Iterative):")
dfs_iterative(graph, '5')
# Out:
# Following is the Depth-First Search (Iterative):
# 5
# 7
# 8
# 3
# 4
# 2

# %% [markdown]
# # Water Jug Problem

# %%
from collections import defaultdict


jug1,jug2,aim = 4,3,2

visited = defaultdict(lambda: False)

def waterJugSolver(amt1, amt2):
  if(amt1 == aim and amt2 == 0) or (amt2 == aim and amt1 == 0):
    print(amt1, amt2)
    return True

  if not visited[(amt1, amt2)]:
    visited[(amt1, amt2)] = True
    print (amt1, amt2)

#recursive
    return(
        waterJugSolver(0, amt2) or
          waterJugSolver(amt1, 0) or
          waterJugSolver(jug1, amt2) or
          waterJugSolver(amt1, jug2) or
        waterJugSolver(
            amt1 + min(amt2, (jug1-amt1)),
            amt2 - min(amt2, (jug1-amt1))
            ) or
        waterJugSolver(
            amt1 - min(amt1, (jug2-amt2)),
            amt2 + min(amt1, (jug2-amt2))
            )
    )
  else:
      return False

print("Steps to reach the solution: ")
if not waterJugSolver(0,0):
  print("No solution")
# Out:
# Steps to reach the solution:
# 0 0
# 4 0
# 4 3
# 0 3
# 3 0
# 3 3
# 4 2
# 0 2

# %% [markdown]
# # Water Jug Problem Exc

# %%
graph = {
    '5' : ['3','7'],
    '3' : ['2','4'],
    '7' : ['8'],
    '2' : [],
    '4' : ['8'],
    '8' : []
}

def dfs_iterative(graph, start_node):
    visited = set()
    stack = [start_node]
    output_stack = []

    while stack:
        node = stack.pop()
        if node not in visited:
            visited.add(node)
            output_stack.append(node)
            stack.extend(graph[node])

    while output_stack:
        print(output_stack.pop())

print("Following is the Depth-First Search:")
dfs_iterative(graph, '5')
# Out:
# Following is the Depth-First Search:
# 2
# 4
# 3
# 8
# 7
# 5

# %%
from collections import defaultdict

jug1, jug2, target = 7, 4, 2

visited = defaultdict(lambda: False)

def water_jug_problem(amt1, amt2):
    """
    Recursive function to solve the water jug problem using DFS with backtrack
    """

    if amt1 == target and amt2 == 0:
        print(f"Goal state reached: ({amt1}, {amt2})")
        return True

    if not visited[(amt1, amt2)]:
        print(f"Current state: ({amt1}, {amt2})")
        visited[(amt1, amt2)] = True

        return (
            water_jug_problem(0, amt2) or
            water_jug_problem(amt1, 0) or
            water_jug_problem(jug1, amt2) or
            water_jug_problem(amt1, jug2) or

            water_jug_problem(
                amt1 + min(amt2, (jug1 - amt1)),
                amt2 - min(amt2, (jug1 - amt1))
            ) or

            water_jug_problem(
                amt1 - min(amt1, (jug2 - amt2)),
                amt2 + min(amt1, (jug2 - amt2))
            )
        )
    else:
        return False

print("Steps to reach the solution:")
if not water_jug_problem(0, 0):
    print("No solution found")
